# %%
# LangChain supports many other chat models. Here, we're using Ollama
from langchain_community.chat_models import ChatOllama
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate


# supports many more optional parameters. Hover on your `ChatOllama(...)`
# class to view the latest available supported parameters
llm = ChatOllama(model="llama3",base_url="https://c66e-34-72-185-215.ngrok-free.app")
prompt = ChatPromptTemplate.from_template("Tell me a short joke about {topic}")

# using LangChain Expressive Language chain syntax
# learn more about the LCEL on
# /docs/concepts/#langchain-expression-language-lcel
chain = prompt | llm | StrOutputParser()

# for brevity, response is printed in terminal
# You can use LangServe to deploy your application for
# production
print(chain.invoke({"topic": "Space travel"}))
# Out:
# Why did the astronaut break up with his girlfriend before going to Mars?
#
# Because he needed space!

# %%
import time
import requests
from requests.exceptions import SSLError

def invoke_chain():
    try:
        response = chain.invoke({"topic": "Space travel"})
        return response
    except SSLError as e:
        print(f"SSLError occurred: {e}")
        print("Retrying in 1 minute...")
        time.sleep(30)  # Wait for 1 minute before retrying
        return invoke_chain()  # Recursively retry

# Main loop
for i in range(20):
    print(i)
    try:
        result = invoke_chain()
        print(result)
    except Exception as e:
        print(f"Error occurred: {e}")
    print("-----------------------------------------------------------------------------------------------------")
# Out:
# 0
# Why did the astronaut break up with his girlfriend before going to Mars?
#
# Because he needed space!
# -----------------------------------------------------------------------------------------------------
# 1
# Why did the astronaut break up with his girlfriend before going to Mars?
#
# Because he needed space! (get it?)
# -----------------------------------------------------------------------------------------------------
# 2
# Why did the astronaut break up with his girlfriend before going to Mars?
#
# Because he needed space!
# -----------------------------------------------------------------------------------------------------
# 3
# Why did the astronaut break up with his girlfriend before going to Mars?
#
# Because he needed space!
# -----------------------------------------------------------------------------------------------------
# 4
# Why did the astronaut break up with his girlfriend before going to Mars?
#
# Because he needed space!
# -----------------------------------------------------------------------------------------------------
# 5
# Why did the astronaut break up with his girlfriend before going to Mars?
#
# Because he needed space!
# -----------------------------------------------------------------------------------------------------
# 6
# Why did the astronaut break up with his girlfriend before going to Mars?
#
# Because he needed space! (get it?)
# -----------------------------------------------------------------------------------------------------
# 7
# Why did the astronaut break up with his girlfriend before going to Mars?
#
# Because he needed space! (get it?)
# -----------------------------------------------------------------------------------------------------
# 8
# Why did the astronaut break up with his girlfriend before going to Mars?
#
# Because he needed space!
# -----------------------------------------------------------------------------------------------------
# 9
# SSLError occurred: HTTPSConnectionPool(host='c66e-34-72-185-215.ngrok-free.app', port=443): Max retries exceeded with url: /api/chat (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1007)')))
# Retrying in 1 minute...
# SSLError occurred: HTTPSConnectionPool(host='c66e-34-72-185-215.ngrok-free.app', port=443): Max retries exceeded with url: /api/chat (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1007)')))
# Retrying in 1 minute...
# Why did the astronaut break up with his girlfriend before going to Mars?
#
# Because he needed space!
# -----------------------------------------------------------------------------------------------------
# 10
# Why did the astronaut break up with his girlfriend before going to Mars?
#
# Because he needed space! (get it?)
# -----------------------------------------------------------------------------------------------------
# 11
# Why did the astronaut break up with his girlfriend before going to Mars?
#
# Because he needed space!
# -----------------------------------------------------------------------------------------------------
# 12
# SSLError occurred: HTTPSConnectionPool(host='c66e-34-72-185-215.ngrok-free.app', port=443): Max retries exceeded with url: /api/chat (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1007)')))
# Retrying in 1 minute...
# SSLError occurred: HTTPSConnectionPool(host='c66e-34-72-185-215.ngrok-free.app', port=443): Max retries exceeded with url: /api/chat (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1007)')))
# Retrying in 1 minute...
# Why did the astronaut break up with his girlfriend before going to Mars?
#
# Because he needed space!
# -----------------------------------------------------------------------------------------------------
# 13
# Why did the astronaut break up with his girlfriend before going to Mars?
#
# Because he needed space!
# -----------------------------------------------------------------------------------------------------
# 14
# Why did the astronaut break up with his girlfriend before going to Mars?
#
# Because he needed space! (get it?)
# -----------------------------------------------------------------------------------------------------
# 15
# Why did the astronaut break up with his girlfriend before going to Mars?
#
# Because he needed space!
# -----------------------------------------------------------------------------------------------------
# 16
# Why did the astronaut break up with his girlfriend before going to Mars?
#
# Because he needed space! (get it?)
# -----------------------------------------------------------------------------------------------------
# 17
# Why did the astronaut break up with his girlfriend before going to Mars?
#
# Because he needed space! (get it?)
# -----------------------------------------------------------------------------------------------------
# 18
# Why did the astronaut break up with his girlfriend before going to Mars?
#
# Because he needed space!
# -----------------------------------------------------------------------------------------------------
# 19
# SSLError occurred: HTTPSConnectionPool(host='c66e-34-72-185-215.ngrok-free.app', port=443): Max retries exceeded with url: /api/chat (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1007)')))
# Retrying in 1 minute...
# SSLError occurred: HTTPSConnectionPool(host='c66e-34-72-185-215.ngrok-free.app', port=443): Max retries exceeded with url: /api/chat (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1007)')))
# Retrying in 1 minute...
# SSLError occurred: HTTPSConnectionPool(host='c66e-34-72-185-215.ngrok-free.app', port=443): Max retries exceeded with url: /api/chat (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1007)')))
# Retrying in 1 minute...
# SSLError occurred: HTTPSConnectionPool(host='c66e-34-72-185-215.ngrok-free.app', port=443): Max retries exceeded with url: /api/chat (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1007)')))
# Retrying in 1 minute...
# SSLError occurred: HTTPSConnectionPool(host='c66e-34-72-185-215.ngrok-free.app', port=443): Max retries exceeded with url: /api/chat (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1007)')))
# Retrying in 1 minute...
# SSLError occurred: HTTPSConnectionPool(host='c66e-34-72-185-215.ngrok-free.app', port=443): Max retries exceeded with url: /api/chat (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1007)')))
# Retrying in 1 minute...
# Why did the astronaut break up with his girlfriend before going to Mars?
#
# Because he needed space!
# -----------------------------------------------------------------------------------------------------
